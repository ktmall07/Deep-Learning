# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab8.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 8: GANs
#
# ### Description
# In this lab, we will build our very first GAN. This can be frustrating at first, but the end result is really cool. We've tried to make the steps intuitive.
#
# Here is what you will learn:
# * GANs are generative models that learn to generate data, based on a min-max/adversarial game between a Generator (G) and Discriminator (D).
# * The parameters of both Generator and Discriminator are optimized with Stochastic Gradient Descent (SGD) or RMSprop or Adam
# * How these concepts translate into PyTorch code for GAN optimization.
#
# Overview of the tutorial:
# 1. GAN intro
# 2. Defining the neural networks in PyTorch, computing a forward pass
# 3. Training our GAN
#
# This lab is modified from https://github.com/tomsercu/gan-tutorial-pytorch
#
# ### Deliverable
# We have provided the GAN architecture for you. Your objective is to:
# 1. Create a DataLoader for the CelebA dataset.
# 2. Create a Dataset and a DataLoader for a dataset from a domain of your choice.
# 3. Implement the original GAN loss
# 4. Implement the training loop and train your GAN.
#
# ### Grading Standards
# - 25% correctly implement the original GAN loss
# - 25% correctly implement the training loop
# - 25% Train on CelebA and display results
# - 25% Train on your own dataset and display results
#
# (you will not be graded on quality of generated images)
#
#
# ### Tips:
# - This lab is complex. Please read through the entire spec before diving in.
# - Also, note that training on this dataset will likely take some time. Please make sure you start early enough to run the training long enough!
# - Expected values: Discriminator Loss will hover around ~ 0.5, Generator Loss should hover around ~ 5.5. You should see discernible results within 1 epoch (~20-30 minutes of training on Colab).

# %% [markdown]
# # Some cool demos:
# * Progress over the last 5 years, from [Ian Goodfellow tweet](https://twitter.com/goodfellow_ian/status/1084973596236144640)
#
# ![tweet image](https://github.com/tomsercu/gan-tutorial-pytorch/blob/master/figs/goodfellow_tweet.jpg?raw=1)
#
# * CycleGAN translating horses into zebras: https://www.youtube.com/watch?v=9reHvktowLY
# * CycleGAN teaser: ![cyclegan teaser image](https://github.com/tomsercu/gan-tutorial-pytorch/blob/master/figs/cyclegan_teaser_high_res.jpg?raw=1)
# * High resolution faces with StyleGAN https://www.youtube.com/watch?v=kSLJriaOumA
# * https://ganbreeder.app web-interface to create images based on [BigGan](https://arxiv.org/abs/1809.11096)

# %% [markdown]
# # 1. GAN first introduction
# [GAN picture](figs/gan_xavigiro.png)
#
# <img src="https://github.com/tomsercu/gan-tutorial-pytorch/blob/master/figs/gan_xavigiro.png?raw=1" alt="GAN picture" style="width: 700px;"/>
#
# GANs are a class of unsupervised generative models which implicitly model the data density.
#
# The basic setup is pictured above. There are two "competing" neural networks:
# * The Generator wants to learn to generate realistic images that are indistinguishable from the real data.
#     - *input*: Gaussian noise random sample. *output*: a (higher dimensional) datapoint
# * The Discriminator wants to tell the real & fake images apart.
#     - *input*: datapoint/image, *output*: probability assigned to datapoint being real. Think binary classifier.
# * The typical analogy: the generator is like a counterfeiter trying to look like real, the discriminator is the police trying to tell counterfeits from the real work.
# * The key novelty of GANs is to pass the error signal (gradients) from the discriminator to the generator: the generator neural network uses the information from the competing discriminator neural network to know how to produce more realistic output.

# %% [markdown]
# Let's start with defining the generator G and discriminator D in pytorch.

# %% [markdown]
# # 2. Define the Generator and Discriminator

# %%
import sys
import pdb
import torch
import torch.nn as nn
import torchvision.datasets
import torchvision.transforms as transforms
import torch.nn.functional as F
import torchvision.utils as vutils

# %matplotlib inline
import matplotlib.pyplot as plt
import os, time

import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.autograd import Variable
from tqdm import tqdm

# You can use whatever display function you want. This is a really simple one that makes decent visualizations
def show_imgs(x, new_fig=True):
    grid = vutils.make_grid(x.detach().cpu(), nrow=8, normalize=True, pad_value=0.3)
    grid = grid.transpose(0,2).transpose(0,1) # channels as last dimension
    if new_fig:
        plt.figure()
    plt.imshow(grid.numpy())

# %% [markdown]
# ## Defining the neural networks

# %%
class Generator(nn.Module):
    # initializers
    def __init__(self, d=128):
        super().__init__()
        self.deconv1 = nn.ConvTranspose2d(100, d*8, 4, 1, 0)
        self.deconv1_bn = nn.BatchNorm2d(d*8)
        self.deconv2 = nn.ConvTranspose2d(d*8, d*4, 4, 2, 1)
        self.deconv2_bn = nn.BatchNorm2d(d*4)
        self.deconv3 = nn.ConvTranspose2d(d*4, d*2, 4, 2, 1)
        self.deconv3_bn = nn.BatchNorm2d(d*2)
        self.deconv4 = nn.ConvTranspose2d(d*2, d, 4, 2, 1)
        self.deconv4_bn = nn.BatchNorm2d(d)
        self.deconv5 = nn.ConvTranspose2d(d, 3, 4, 2, 1)

    # forward method
    def forward(self, x):
        x = F.relu(self.deconv1_bn(self.deconv1(x)))
        x = F.relu(self.deconv2_bn(self.deconv2(x)))
        x = F.relu(self.deconv3_bn(self.deconv3(x)))
        x = F.relu(self.deconv4_bn(self.deconv4(x)))
        x = torch.tanh(self.deconv5(x))

        return x

# %%
class Discriminator(nn.Module):
    # initializers
    def __init__(self, d=128):
        super().__init__()
        self.conv1 = nn.Conv2d(3, d, 4, 2, 1)
        self.conv2 = nn.Conv2d(d, d*2, 4, 2, 1)
        self.conv2_bn = nn.BatchNorm2d(d*2)
        self.conv3 = nn.Conv2d(d*2, d*4, 4, 2, 1)
        self.conv3_bn = nn.BatchNorm2d(d*4)
        self.conv4 = nn.Conv2d(d*4, d*8, 4, 2, 1)
        self.conv4_bn = nn.BatchNorm2d(d*8)
        self.conv5 = nn.Conv2d(d*8, 1, 4, 1, 0)

    # forward method
    def forward(self, x):
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2_bn(self.conv2(x)), 0.2)
        x = F.leaky_relu(self.conv3_bn(self.conv3(x)), 0.2)
        x = F.leaky_relu(self.conv4_bn(self.conv4(x)), 0.2)
        x = torch.sigmoid(self.conv5(x))

        return x

# %%
#####
# instantiate a Generator and Discriminator according to their class definition.
#####

D = Discriminator(128)
G = Generator(128)

print(D)
print(G)
# Out:
# Discriminator(
#   (conv1): Conv2d(3, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv2_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv3_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv4_bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(1024, 1, kernel_size=(4, 4), stride=(1, 1))
# )
# Generator(
#   (deconv1): ConvTranspose2d(100, 1024, kernel_size=(4, 4), stride=(1, 1))
#   (deconv1_bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv2): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (deconv2_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (deconv3_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv4): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (deconv4_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deconv5): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
# )

# %% [markdown]
# ## Testing the neural networks (forward pass)

# %%
samples = torch.randn(5, 3, 64,64) # batch size x channels x width x height
D(samples)
# Out:
# tensor([[[[0.4857]]],
#
#
#         [[[0.4908]]],
#
#
#         [[[0.5323]]],
#
#
#         [[[0.6603]]],
#
#
#         [[[0.5374]]]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# Things to try:
# * What happens if you change the number of samples in a batch?
# * What happens if you change the width/height of the input?
# * What are the weights of the discriminator? You can get an iterator over them with `.parameters()` and `.named_parameters()`

# %%
for name, p in D.named_parameters():
    print(name, p.shape)
# Out:
# conv1.weight torch.Size([128, 3, 4, 4])
# conv1.bias torch.Size([128])
# conv2.weight torch.Size([256, 128, 4, 4])
# conv2.bias torch.Size([256])
# conv2_bn.weight torch.Size([256])
# conv2_bn.bias torch.Size([256])
# conv3.weight torch.Size([512, 256, 4, 4])
# conv3.bias torch.Size([512])
# conv3_bn.weight torch.Size([512])
# conv3_bn.bias torch.Size([512])
# conv4.weight torch.Size([1024, 512, 4, 4])
# conv4.bias torch.Size([1024])
# conv4_bn.weight torch.Size([1024])
# conv4_bn.bias torch.Size([1024])
# conv5.weight torch.Size([1, 1024, 4, 4])
# conv5.bias torch.Size([1])

# %% [markdown]
# We will think of the concatentation of all these discriminator weights in one big vector as $\theta_D$.
#
# Similarly we name the concatentation of all the generator weights in one big vector $\theta_G$.

# %%
for name, p in G.named_parameters():
    print(name, p.shape)
# Out:
# deconv1.weight torch.Size([100, 1024, 4, 4])
# deconv1.bias torch.Size([1024])
# deconv1_bn.weight torch.Size([1024])
# deconv1_bn.bias torch.Size([1024])
# deconv2.weight torch.Size([1024, 512, 4, 4])
# deconv2.bias torch.Size([512])
# deconv2_bn.weight torch.Size([512])
# deconv2_bn.bias torch.Size([512])
# deconv3.weight torch.Size([512, 256, 4, 4])
# deconv3.bias torch.Size([256])
# deconv3_bn.weight torch.Size([256])
# deconv3_bn.bias torch.Size([256])
# deconv4.weight torch.Size([256, 128, 4, 4])
# deconv4.bias torch.Size([128])
# deconv4_bn.weight torch.Size([128])
# deconv4_bn.bias torch.Size([128])
# deconv5.weight torch.Size([128, 3, 4, 4])
# deconv5.bias torch.Size([3])

# %%
# A small batch of 2 samples, random noise.
z = torch.randn(2, 100).view(-1,100,1,1)
x_gen = G(z)
#notice that the generated value is a batch of 2 images
x_gen.shape
# Out:
# torch.Size([2, 3, 64, 64])

# %%
z = torch.randn(8, 100).view(-1,100,1,1).cuda()
G = G.cuda()
show_imgs(G(z))

# %% [markdown]
# In traditional deep learning, you measure performance by looking at the loss value. In GANs, this does not work well because we are performing a Min-Max and the loss values may not be intuitively lower when the network is doing well.
#
# So, performance must be measured qualitatively, by looking at images. Therefore, you can sample random $z$ vectors every pass through the network to see how "novel" the generation is becoming. And you can also sample a single $z$ vector that is passed through the network every time to see how a single example progresses during training.

# %%
fixed_z_ = torch.randn((5 * 5, 100)).view(-1, 100, 1, 1)    # fixed noise
fixed_z_ = Variable(fixed_z_.cuda(), requires_grad=False)

# %% [markdown]
# ## Loading the data and computing forward pass

# %%
# !wget 'https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/celeba.zip'
# Out:
# --2022-03-06 06:19:41--  https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/celeba.zip
# Resolving s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)... 52.219.112.200
# Connecting to s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)|52.219.112.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1443490838 (1.3G) [application/zip]
# Saving to: ‘celeba.zip’
#
# celeba.zip          100%[===================>]   1.34G  20.5MB/s    in 69s
#
# 2022-03-06 06:20:51 (20.0 MB/s) - ‘celeba.zip’ saved [1443490838/1443490838]

# %%
# !unzip /content/celeba.zip -d data
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: data/img_align_celeba/197600.jpg
#  extracting: data/img_align_celeba/197601.jpg
#  extracting: data/img_align_celeba/197602.jpg
#  extracting: data/img_align_celeba/197603.jpg
#  extracting: data/img_align_celeba/197604.jpg
#  extracting: data/img_align_celeba/197605.jpg
#  extracting: data/img_align_celeba/197606.jpg
#  extracting: data/img_align_celeba/197607.jpg
#  extracting: data/img_align_celeba/197608.jpg
#  extracting: data/img_align_celeba/197609.jpg
#  extracting: data/img_align_celeba/197610.jpg
#  extracting: data/img_align_celeba/197611.jpg
#  extracting: data/img_align_celeba/197612.jpg
#  extracting: data/img_align_celeba/197613.jpg
#  extracting: data/img_align_celeba/197614.jpg
#  extracting: data/img_align_celeba/197615.jpg
#  extracting: data/img_align_celeba/197616.jpg
#  extracting: data/img_align_celeba/197617.jpg
#  extracting: data/img_align_celeba/197618.jpg
#  extracting: data/img_align_celeba/197619.jpg
#  extracting: data/img_align_celeba/197620.jpg
#  extracting: data/img_align_celeba/197621.jpg
#  extracting: data/img_align_celeba/197622.jpg
#  extracting: data/img_align_celeba/197623.jpg
#  extracting: data/img_align_celeba/197624.jpg
#  extracting: data/img_align_celeba/197625.jpg
#  extracting: data/img_align_celeba/197626.jpg
#  extracting: data/img_align_celeba/197627.jpg
#  extracting: data/img_align_celeba/197628.jpg
#  extracting: data/img_align_celeba/197629.jpg
#  extracting: data/img_align_celeba/197630.jpg
#  extracting: data/img_align_celeba/197631.jpg
#  extracting: data/img_align_celeba/197632.jpg
#  extracting: data/img_align_celeba/197633.jpg
#  extracting: data/img_align_celeba/197634.jpg
#  extracting: data/img_align_celeba/197635.jpg
#  extracting: data/img_align_celeba/197636.jpg
#  extracting: data/img_align_celeba/197637.jpg
#  extracting: data/img_align_celeba/197638.jpg
#  extracting: data/img_align_celeba/197639.jpg
#  extracting: data/img_align_celeba/197640.jpg
#  extracting: data/img_align_celeba/197641.jpg
#  extracting: data/img_align_celeba/197642.jpg
#  extracting: data/img_align_celeba/197643.jpg
#  extracting: data/img_align_celeba/197644.jpg
#  extracting: data/img_align_celeba/197645.jpg
#  extracting: data/img_align_celeba/197646.jpg
#  extracting: data/img_align_celeba/197647.jpg
#  extracting: data/img_align_celeba/197648.jpg
#  extracting: data/img_align_celeba/197649.jpg
#  extracting: data/img_align_celeba/197650.jpg
#  extracting: data/img_align_celeba/197651.jpg
#  extracting: data/img_align_celeba/197652.jpg
#  extracting: data/img_align_celeba/197653.jpg
#  extracting: data/img_align_celeba/197654.jpg
#  extracting: data/img_align_celeba/197655.jpg
#  extracting: data/img_align_celeba/197656.jpg
#  extracting: data/img_align_celeba/197657.jpg
#  extracting: data/img_align_celeba/197658.jpg
#  extracting: data/img_align_celeba/197659.jpg
#  extracting: data/img_align_celeba/197660.jpg
#  extracting: data/img_align_celeba/197661.jpg
#  extracting: data/img_align_celeba/197662.jpg
#  extracting: data/img_align_celeba/197663.jpg
#  extracting: data/img_align_celeba/197664.jpg
#  extracting: data/img_align_celeba/197665.jpg
#  extracting: data/img_align_celeba/197666.jpg
#  extracting: data/img_align_celeba/197667.jpg
#  extracting: data/img_align_celeba/197668.jpg
#  extracting: data/img_align_celeba/197669.jpg
#  extracting: data/img_align_celeba/197670.jpg
#  extracting: data/img_align_celeba/197671.jpg
#  extracting: data/img_align_celeba/197672.jpg
#  extracting: data/img_align_celeba/197673.jpg
#  extracting: data/img_align_celeba/197674.jpg
#  extracting: data/img_align_celeba/197675.jpg
#  extracting: data/img_align_celeba/197676.jpg
#  extracting: data/img_align_celeba/197677.jpg
#  extracting: data/img_align_celeba/197678.jpg
#  extracting: data/img_align_celeba/197679.jpg
#  extracting: data/img_align_celeba/197680.jpg
#  extracting: data/img_align_celeba/197681.jpg
#  extracting: data/img_align_celeba/197682.jpg
#  extracting: data/img_align_celeba/197683.jpg
#  extracting: data/img_align_celeba/197684.jpg
#  extracting: data/img_align_celeba/197685.jpg
#  extracting: data/img_align_celeba/197686.jpg
#  extracting: data/img_align_celeba/197687.jpg
#  extracting: data/img_align_celeba/197688.jpg
#  extracting: data/img_align_celeba/197689.jpg
#  extracting: data/img_align_celeba/197690.jpg
#  extracting: data/img_align_celeba/197691.jpg
#  extracting: data/img_align_celeba/197692.jpg
#  extracting: data/img_align_celeba/197693.jpg
#  extracting: data/img_align_celeba/197694.jpg
#  extracting: data/img_align_celeba/197695.jpg
#  extracting: data/img_align_celeba/197696.jpg
#  extracting: data/img_align_celeba/197697.jpg
#  extracting: data/img_align_celeba/197698.jpg
#  extracting: data/img_align_celeba/197699.jpg
#  extracting: data/img_align_celeba/197700.jpg
#  extracting: data/img_align_celeba/197701.jpg
#  extracting: data/img_align_celeba/197702.jpg
#  extracting: data/img_align_celeba/197703.jpg
#  extracting: data/img_align_celeba/197704.jpg
#  extracting: data/img_align_celeba/197705.jpg
#  extracting: data/img_align_celeba/197706.jpg
#  extracting: data/img_align_celeba/197707.jpg
#  extracting: data/img_align_celeba/197708.jpg
#  extracting: data/img_align_celeba/197709.jpg
#  extracting: data/img_align_celeba/197710.jpg
#  extracting: data/img_align_celeba/197711.jpg
#  extracting: data/img_align_celeba/197712.jpg
#  extracting: data/img_align_celeba/197713.jpg
#  extracting: data/img_align_celeba/197714.jpg
#  extracting: data/img_align_celeba/197715.jpg
#  extracting: data/img_align_celeba/197716.jpg
#  extracting: data/img_align_celeba/197717.jpg
#  extracting: data/img_align_celeba/197718.jpg
#  extracting: data/img_align_celeba/197719.jpg
#  extracting: data/img_align_celeba/197720.jpg
#  extracting: data/img_align_celeba/197721.jpg
#  extracting: data/img_align_celeba/197722.jpg
#  extracting: data/img_align_celeba/197723.jpg
#  extracting: data/img_align_celeba/197724.jpg
#  extracting: data/img_align_celeba/197725.jpg
#  extracting: data/img_align_celeba/197726.jpg
#  extracting: data/img_align_celeba/197727.jpg
#  extracting: data/img_align_celeba/197728.jpg
#  extracting: data/img_align_celeba/197729.jpg
#  extracting: data/img_align_celeba/197730.jpg
#  extracting: data/img_align_celeba/197731.jpg
#  extracting: data/img_align_celeba/197732.jpg
#  extracting: data/img_align_celeba/197733.jpg
#  extracting: data/img_align_celeba/197734.jpg
#  extracting: data/img_align_celeba/197735.jpg
#  extracting: data/img_align_celeba/197736.jpg
#  extracting: data/img_align_celeba/197737.jpg
#  extracting: data/img_align_celeba/197738.jpg
#  extracting: data/img_align_celeba/197739.jpg
#  extracting: data/img_align_celeba/197740.jpg
#  extracting: data/img_align_celeba/197741.jpg
#  extracting: data/img_align_celeba/197742.jpg
#  extracting: data/img_align_celeba/197743.jpg
#  extracting: data/img_align_celeba/197744.jpg
#  extracting: data/img_align_celeba/197745.jpg
#  extracting: data/img_align_celeba/197746.jpg
#  extracting: data/img_align_celeba/197747.jpg
#  extracting: data/img_align_celeba/197748.jpg
#  extracting: data/img_align_celeba/197749.jpg
#  extracting: data/img_align_celeba/197750.jpg
#  extracting: data/img_align_celeba/197751.jpg
#  extracting: data/img_align_celeba/197752.jpg
#  extracting: data/img_align_celeba/197753.jpg
#  extracting: data/img_align_celeba/197754.jpg
#  extracting: data/img_align_celeba/197755.jpg
#  extracting: data/img_align_celeba/197756.jpg
#  extracting: data/img_align_celeba/197757.jpg
#  extracting: data/img_align_celeba/197758.jpg
#  extracting: data/img_align_celeba/197759.jpg
#  extracting: data/img_align_celeba/197760.jpg
#  extracting: data/img_align_celeba/197761.jpg
#  extracting: data/img_align_celeba/197762.jpg
#  extracting: data/img_align_celeba/197763.jpg
#  extracting: data/img_align_celeba/197764.jpg
#  extracting: data/img_align_celeba/197765.jpg
#  extracting: data/img_align_celeba/197766.jpg
#  extracting: data/img_align_celeba/197767.jpg
#  extracting: data/img_align_celeba/197768.jpg
#  extracting: data/img_align_celeba/197769.jpg
#  extracting: data/img_align_celeba/197770.jpg
#  extracting: data/img_align_celeba/197771.jpg
#  extracting: data/img_align_celeba/197772.jpg
#  extracting: data/img_align_celeba/197773.jpg
#  extracting: data/img_align_celeba/197774.jpg
#  extracting: data/img_align_celeba/197775.jpg
#  extracting: data/img_align_celeba/197776.jpg
#  extracting: data/img_align_celeba/197777.jpg
#  extracting: data/img_align_celeba/197778.jpg
#  extracting: data/img_align_celeba/197779.jpg
#  extracting: data/img_align_celeba/197780.jpg
#  extracting: data/img_align_celeba/197781.jpg
#  extracting: data/img_align_celeba/197782.jpg
#  extracting: data/img_align_celeba/197783.jpg
#  extracting: data/img_align_celeba/197784.jpg
#  extracting: data/img_align_celeba/197785.jpg
#  extracting: data/img_align_celeba/197786.jpg
#  extracting: data/img_align_celeba/197787.jpg
#  extracting: data/img_align_celeba/197788.jpg
#  extracting: data/img_align_celeba/197789.jpg
#  extracting: data/img_align_celeba/197790.jpg
#  extracting: data/img_align_celeba/197791.jpg
#  extracting: data/img_align_celeba/197792.jpg
#  extracting: data/img_align_celeba/197793.jpg
#  extracting: data/img_align_celeba/197794.jpg
#  extracting: data/img_align_celeba/197795.jpg
#  extracting: data/img_align_celeba/197796.jpg
#  extracting: data/img_align_celeba/197797.jpg
#  extracting: data/img_align_celeba/197798.jpg
#  extracting: data/img_align_celeba/197799.jpg
#  extracting: data/img_align_celeba/197800.jpg
#  extracting: data/img_align_celeba/197801.jpg
#  extracting: data/img_align_celeba/197802.jpg
#  extracting: data/img_align_celeba/197803.jpg
#  extracting: data/img_align_celeba/197804.jpg
#  extracting: data/img_align_celeba/197805.jpg
#  extracting: data/img_align_celeba/197806.jpg
#  extracting: data/img_align_celeba/197807.jpg
#  extracting: data/img_align_celeba/197808.jpg
#  extracting: data/img_align_celeba/197809.jpg
#  extracting: data/img_align_celeba/197810.jpg
#  extracting: data/img_align_celeba/197811.jpg
#  extracting: data/img_align_celeba/197812.jpg
#  extracting: data/img_align_celeba/197813.jpg
#  extracting: data/img_align_celeba/197814.jpg
#  extracting: data/img_align_celeba/197815.jpg
#  extracting: data/img_align_celeba/197816.jpg
#  extracting: data/img_align_celeba/197817.jpg
#  extracting: data/img_align_celeba/197818.jpg
#  extracting: data/img_align_celeba/197819.jpg
#  extracting: data/img_align_celeba/197820.jpg
#  extracting: data/img_align_celeba/197821.jpg
#  extracting: data/img_align_celeba/197822.jpg
#  extracting: data/img_align_celeba/197823.jpg
#  extracting: data/img_align_celeba/197824.jpg
#  extracting: data/img_align_celeba/197825.jpg
#  extracting: data/img_align_celeba/197826.jpg
#  extracting: data/img_align_celeba/197827.jpg
#  extracting: data/img_align_celeba/197828.jpg
#  extracting: data/img_align_celeba/197829.jpg
#  extracting: data/img_align_celeba/197830.jpg
#  extracting: data/img_align_celeba/197831.jpg
#  extracting: data/img_align_celeba/197832.jpg
#  extracting: data/img_align_celeba/197833.jpg
#  extracting: data/img_align_celeba/197834.jpg
#  extracting: data/img_align_celeba/197835.jpg
#  extracting: data/img_align_celeba/197836.jpg
#  extracting: data/img_align_celeba/197837.jpg
#  extracting: data/img_align_celeba/197838.jpg
#  extracting: data/img_align_celeba/197839.jpg
#  extracting: data/img_align_celeba/197840.jpg
#  extracting: data/img_align_celeba/197841.jpg
#  extracting: data/img_align_celeba/197842.jpg
#  extracting: data/img_align_celeba/197843.jpg
#  extracting: data/img_align_celeba/197844.jpg
#  extracting: data/img_align_celeba/197845.jpg
#  extracting: data/img_align_celeba/197846.jpg
#  extracting: data/img_align_celeba/197847.jpg
#  extracting: data/img_align_celeba/197848.jpg
#  extracting: data/img_align_celeba/197849.jpg
#  extracting: data/img_align_celeba/197850.jpg
#  extracting: data/img_align_celeba/197851.jpg
#  extracting: data/img_align_celeba/197852.jpg
#  extracting: data/img_align_celeba/197853.jpg
#  extracting: data/img_align_celeba/197854.jpg
#  extracting: data/img_align_celeba/197855.jpg
#  extracting: data/img_align_celeba/197856.jpg
#  extracting: data/img_align_celeba/197857.jpg
#  extracting: data/img_align_celeba/197858.jpg
#  extracting: data/img_align_celeba/197859.jpg
#  extracting: data/img_align_celeba/197860.jpg
#  extracting: data/img_align_celeba/197861.jpg
#  extracting: data/img_align_celeba/197862.jpg
#  extracting: data/img_align_celeba/197863.jpg
#  extracting: data/img_align_celeba/197864.jpg
#  extracting: data/img_align_celeba/197865.jpg
#  extracting: data/img_align_celeba/197866.jpg
#  extracting: data/img_align_celeba/197867.jpg
#  extracting: data/img_align_celeba/197868.jpg
#  extracting: data/img_align_celeba/197869.jpg
#  extracting: data/img_align_celeba/197870.jpg
#  extracting: data/img_align_celeba/197871.jpg
#  extracting: data/img_align_celeba/197872.jpg
#  extracting: data/img_align_celeba/197873.jpg
#  extracting: data/img_align_celeba/197874.jpg
#  extracting: data/img_align_celeba/197875.jpg
#  extracting: data/img_align_celeba/197876.jpg
#  extracting: data/img_align_celeba/197877.jpg
#  extracting: data/img_align_celeba/197878.jpg
#  extracting: data/img_align_celeba/197879.jpg
#  extracting: data/img_align_celeba/197880.jpg
#  extracting: data/img_align_celeba/197881.jpg
#  extracting: data/img_align_celeba/197882.jpg
#  extracting: data/img_align_celeba/197883.jpg
#  extracting: data/img_align_celeba/197884.jpg
#  extracting: data/img_align_celeba/197885.jpg
#  extracting: data/img_align_celeba/197886.jpg
#  extracting: data/img_align_celeba/197887.jpg
#  extracting: data/img_align_celeba/197888.jpg
#  extracting: data/img_align_celeba/197889.jpg
#  extracting: data/img_align_celeba/197890.jpg
#  extracting: data/img_align_celeba/197891.jpg
#  extracting: data/img_align_celeba/197892.jpg
#  extracting: data/img_align_celeba/197893.jpg
#  extracting: data/img_align_celeba/197894.jpg
#  extracting: data/img_align_celeba/197895.jpg
#  extracting: data/img_align_celeba/197896.jpg
#  extracting: data/img_align_celeba/197897.jpg
#  extracting: data/img_align_celeba/197898.jpg
#  extracting: data/img_align_celeba/197899.jpg
#  extracting: data/img_align_celeba/197900.jpg
#  extracting: data/img_align_celeba/197901.jpg
#  extracting: data/img_align_celeba/197902.jpg
#  extracting: data/img_align_celeba/197903.jpg
#  extracting: data/img_align_celeba/197904.jpg
#  extracting: data/img_align_celeba/197905.jpg
#  extracting: data/img_align_celeba/197906.jpg
#  extracting: data/img_align_celeba/197907.jpg
#  extracting: data/img_align_celeba/197908.jpg
#  extracting: data/img_align_celeba/197909.jpg
#  extracting: data/img_align_celeba/197910.jpg
#  extracting: data/img_align_celeba/197911.jpg
#  extracting: data/img_align_celeba/197912.jpg
#  extracting: data/img_align_celeba/197913.jpg
#  extracting: data/img_align_celeba/197914.jpg
#  extracting: data/img_align_celeba/197915.jpg
#  extracting: data/img_align_celeba/197916.jpg
#  extracting: data/img_align_celeba/197917.jpg
#  extracting: data/img_align_celeba/197918.jpg
#  extracting: data/img_align_celeba/197919.jpg
#  extracting: data/img_align_celeba/197920.jpg
#  extracting: data/img_align_celeba/197921.jpg
#  extracting: data/img_align_celeba/197922.jpg
#  extracting: data/img_align_celeba/197923.jpg
#  extracting: data/img_align_celeba/197924.jpg
#  extracting: data/img_align_celeba/197925.jpg
#  extracting: data/img_align_celeba/197926.jpg
#  extracting: data/img_align_celeba/197927.jpg
#  extracting: data/img_align_celeba/197928.jpg
#  extracting: data/img_align_celeba/197929.jpg
#  extracting: data/img_align_celeba/197930.jpg
#  extracting: data/img_align_celeba/197931.jpg
#  extracting: data/img_align_celeba/197932.jpg
#  extracting: data/img_align_celeba/197933.jpg
#  extracting: data/img_align_celeba/197934.jpg
#  extracting: data/img_align_celeba/197935.jpg
#  extracting: data/img_align_celeba/197936.jpg
#  extracting: data/img_align_celeba/197937.jpg
#  extracting: data/img_align_celeba/197938.jpg
#  extracting: data/img_align_celeba/197939.jpg
#  extracting: data/img_align_celeba/197940.jpg
#  extracting: data/img_align_celeba/197941.jpg
#  extracting: data/img_align_celeba/197942.jpg
#  extracting: data/img_align_celeba/197943.jpg
#  extracting: data/img_align_celeba/197944.jpg
#  extracting: data/img_align_celeba/197945.jpg
#  extracting: data/img_align_celeba/197946.jpg
#  extracting: data/img_align_celeba/197947.jpg
#  extracting: data/img_align_celeba/197948.jpg
#  extracting: data/img_align_celeba/197949.jpg
#  extracting: data/img_align_celeba/197950.jpg
#  extracting: data/img_align_celeba/197951.jpg
#  extracting: data/img_align_celeba/197952.jpg
#  extracting: data/img_align_celeba/197953.jpg
#  extracting: data/img_align_celeba/197954.jpg
#  extracting: data/img_align_celeba/197955.jpg
#  extracting: data/img_align_celeba/197956.jpg
#  extracting: data/img_align_celeba/197957.jpg
#  extracting: data/img_align_celeba/197958.jpg
#  extracting: data/img_align_celeba/197959.jpg
#  extracting: data/img_align_celeba/197960.jpg
#  extracting: data/img_align_celeba/197961.jpg
#  extracting: data/img_align_celeba/197962.jpg
#  extracting: data/img_align_celeba/197963.jpg
#  extracting: data/img_align_celeba/197964.jpg
#  extracting: data/img_align_celeba/197965.jpg
#  extracting: data/img_align_celeba/197966.jpg
#  extracting: data/img_align_celeba/197967.jpg
#  extracting: data/img_align_celeba/197968.jpg
#  extracting: data/img_align_celeba/197969.jpg
#  extracting: data/img_align_celeba/197970.jpg
#  extracting: data/img_align_celeba/197971.jpg
#  extracting: data/img_align_celeba/197972.jpg
#  extracting: data/img_align_celeba/197973.jpg
#  extracting: data/img_align_celeba/197974.jpg
#  extracting: data/img_align_celeba/197975.jpg
#  extracting: data/img_align_celeba/197976.jpg
#  extracting: data/img_align_celeba/197977.jpg
#  extracting: data/img_align_celeba/197978.jpg
#  extracting: data/img_align_celeba/197979.jpg
#  extracting: data/img_align_celeba/197980.jpg
#  extracting: data/img_align_celeba/197981.jpg
#  extracting: data/img_align_celeba/197982.jpg
#  extracting: data/img_align_celeba/197983.jpg
#  extracting: data/img_align_celeba/197984.jpg
#  extracting: data/img_align_celeba/197985.jpg
#  extracting: data/img_align_celeba/197986.jpg
#  extracting: data/img_align_celeba/197987.jpg
#  extracting: data/img_align_celeba/197988.jpg
#  extracting: data/img_align_celeba/197989.jpg
#  extracting: data/img_align_celeba/197990.jpg
#  extracting: data/img_align_celeba/197991.jpg
#  extracting: data/img_align_celeba/197992.jpg
#  extracting: data/img_align_celeba/197993.jpg
#  extracting: data/img_align_celeba/197994.jpg
#  extracting: data/img_align_celeba/197995.jpg
#  extracting: data/img_align_celeba/197996.jpg
#  extracting: data/img_align_celeba/197997.jpg
#  extracting: data/img_align_celeba/197998.jpg
#  extracting: data/img_align_celeba/197999.jpg
#  extracting: data/img_align_celeba/198000.jpg
#  extracting: data/img_align_celeba/198001.jpg
#  extracting: data/img_align_celeba/198002.jpg
#  extracting: data/img_align_celeba/198003.jpg
#  extracting: data/img_align_celeba/198004.jpg
#  extracting: data/img_align_celeba/198005.jpg
#  extracting: data/img_align_celeba/198006.jpg
#  extracting: data/img_align_celeba/198007.jpg
#  extracting: data/img_align_celeba/198008.jpg
#  extracting: data/img_align_celeba/198009.jpg
#  extracting: data/img_align_celeba/198010.jpg
#  extracting: data/img_align_celeba/198011.jpg
#  extracting: data/img_align_celeba/198012.jpg
#  extracting: data/img_align_celeba/198013.jpg
#  extracting: data/img_align_celeba/198014.jpg
#  extracting: data/img_align_celeba/198015.jpg
#  extracting: data/img_align_celeba/198016.jpg
#  extracting: data/img_align_celeba/198017.jpg
#  extracting: data/img_align_celeba/198018.jpg
#  extracting: data/img_align_celeba/198019.jpg
#  extracting: data/img_align_celeba/198020.jpg
#  extracting: data/img_align_celeba/198021.jpg
#  extracting: data/img_align_celeba/198022.jpg
#  extracting: data/img_align_celeba/198023.jpg
#  extracting: data/img_align_celeba/198024.jpg
#  extracting: data/img_align_celeba/198025.jpg
#  extracting: data/img_align_celeba/198026.jpg
#  extracting: data/img_align_celeba/198027.jpg
#  extracting: data/img_align_celeba/198028.jpg
#  extracting: data/img_align_celeba/198029.jpg
#  extracting: data/img_align_celeba/198030.jpg
#  extracting: data/img_align_celeba/198031.jpg
#  extracting: data/img_align_celeba/198032.jpg
#  extracting: data/img_align_celeba/198033.jpg
#  extracting: data/img_align_celeba/198034.jpg
#  extracting: data/img_align_celeba/198035.jpg
#  extracting: data/img_align_celeba/198036.jpg
#  extracting: data/img_align_celeba/198037.jpg
#  extracting: data/img_align_celeba/198038.jpg
#  extracting: data/img_align_celeba/198039.jpg
#  extracting: data/img_align_celeba/198040.jpg
#  extracting: data/img_align_celeba/198041.jpg
#  extracting: data/img_align_celeba/198042.jpg
#  extracting: data/img_align_celeba/198043.jpg
#  extracting: data/img_align_celeba/198044.jpg
#  extracting: data/img_align_celeba/198045.jpg
#  extracting: data/img_align_celeba/198046.jpg
#  extracting: data/img_align_celeba/198047.jpg
#  extracting: data/img_align_celeba/198048.jpg
#  extracting: data/img_align_celeba/198049.jpg
#  extracting: data/img_align_celeba/198050.jpg
#  extracting: data/img_align_celeba/198051.jpg
#  extracting: data/img_align_celeba/198052.jpg
#  extracting: data/img_align_celeba/198053.jpg
#  extracting: data/img_align_celeba/198054.jpg
#  extracting: data/img_align_celeba/198055.jpg
#  extracting: data/img_align_celeba/198056.jpg
#  extracting: data/img_align_celeba/198057.jpg
#  extracting: data/img_align_celeba/198058.jpg
#  extracting: data/img_align_celeba/198059.jpg
#  extracting: data/img_align_celeba/198060.jpg
#  extracting: data/img_align_celeba/198061.jpg
#  extracting: data/img_align_celeba/198062.jpg
#  extracting: data/img_align_celeba/198063.jpg
#  extracting: data/img_align_celeba/198064.jpg
#  extracting: data/img_align_celeba/198065.jpg
#  extracting: data/img_align_celeba/198066.jpg
#  extracting: data/img_align_celeba/198067.jpg
#  extracting: data/img_align_celeba/198068.jpg
#  extracting: data/img_align_celeba/198069.jpg
#  extracting: data/img_align_celeba/198070.jpg
#  extracting: data/img_align_celeba/198071.jpg
#  extracting: data/img_align_celeba/198072.jpg
#  extracting: data/img_align_celeba/198073.jpg
#  extracting: data/img_align_celeba/198074.jpg
#  extracting: data/img_align_celeba/198075.jpg
#  extracting: data/img_align_celeba/198076.jpg
#  extracting: data/img_align_celeba/198077.jpg
#  extracting: data/img_align_celeba/198078.jpg
#  extracting: data/img_align_celeba/198079.jpg
#  extracting: data/img_align_celeba/198080.jpg
#  extracting: data/img_align_celeba/198081.jpg
#  extracting: data/img_align_celeba/198082.jpg
#  extracting: data/img_align_celeba/198083.jpg
#  extracting: data/img_align_celeba/198084.jpg
#  extracting: data/img_align_celeba/198085.jpg
#  extracting: data/img_align_celeba/198086.jpg
#  extracting: data/img_align_celeba/198087.jpg
#  extracting: data/img_align_celeba/198088.jpg
#  extracting: data/img_align_celeba/198089.jpg
#  extracting: data/img_align_celeba/198090.jpg
#  extracting: data/img_align_celeba/198091.jpg
#  extracting: data/img_align_celeba/198092.jpg
#  extracting: data/img_align_celeba/198093.jpg
#  extracting: data/img_align_celeba/198094.jpg
#  extracting: data/img_align_celeba/198095.jpg
#  extracting: data/img_align_celeba/198096.jpg
#  extracting: data/img_align_celeba/198097.jpg
#  extracting: data/img_align_celeba/198098.jpg
#  extracting: data/img_align_celeba/198099.jpg
#  extracting: data/img_align_celeba/198100.jpg
#  extracting: data/img_align_celeba/198101.jpg
#  extracting: data/img_align_celeba/198102.jpg
#  extracting: data/img_align_celeba/198103.jpg
#  extracting: data/img_align_celeba/198104.jpg
#  extracting: data/img_align_celeba/198105.jpg
#  extracting: data/img_align_celeba/198106.jpg
#  extracting: data/img_align_celeba/198107.jpg
#  extracting: data/img_align_celeba/198108.jpg
#  extracting: data/img_align_celeba/198109.jpg
#  extracting: data/img_align_celeba/198110.jpg
#  extracting: data/img_align_celeba/198111.jpg
#  extracting: data/img_align_celeba/198112.jpg
#  extracting: data/img_align_celeba/198113.jpg
#  extracting: data/img_align_celeba/198114.jpg
#  extracting: data/img_align_celeba/198115.jpg
#  extracting: data/img_align_celeba/198116.jpg
#  extracting: data/img_align_celeba/198117.jpg
#  extracting: data/img_align_celeba/198118.jpg
#  extracting: data/img_align_celeba/198119.jpg
#  extracting: data/img_align_celeba/198120.jpg
#  extracting: data/img_align_celeba/198121.jpg
#  extracting: data/img_align_celeba/198122.jpg
#  extracting: data/img_align_celeba/198123.jpg
#  extracting: data/img_align_celeba/198124.jpg
#  extracting: data/img_align_celeba/198125.jpg
#  extracting: data/img_align_celeba/198126.jpg
#  extracting: data/img_align_celeba/198127.jpg
#  extracting: data/img_align_celeba/198128.jpg
#  extracting: data/img_align_celeba/198129.jpg
#  extracting: data/img_align_celeba/198130.jpg
#  extracting: data/img_align_celeba/198131.jpg
#  extracting: data/img_align_celeba/198132.jpg
#  extracting: data/img_align_celeba/198133.jpg
#  extracting: data/img_align_celeba/198134.jpg
#  extracting: data/img_align_celeba/198135.jpg
#  extracting: data/img_align_celeba/198136.jpg
#  extracting: data/img_align_celeba/198137.jpg
#  extracting: data/img_align_celeba/198138.jpg
#  extracting: data/img_align_celeba/198139.jpg
#  extracting: data/img_align_celeba/198140.jpg
#  extracting: data/img_align_celeba/198141.jpg
#  extracting: data/img_align_celeba/198142.jpg
#  extracting: data/img_align_celeba/198143.jpg
#  extracting: data/img_align_celeba/198144.jpg
#  extracting: data/img_align_celeba/198145.jpg
#  extracting: data/img_align_celeba/198146.jpg
#  extracting: data/img_align_celeba/198147.jpg
#  extracting: data/img_align_celeba/198148.jpg
#  extracting: data/img_align_celeba/198149.jpg
#  extracting: data/img_align_celeba/198150.jpg
#  extracting: data/img_align_celeba/198151.jpg
#  extracting: data/img_align_celeba/198152.jpg
#  extracting: data/img_align_celeba/198153.jpg
#  extracting: data/img_align_celeba/198154.jpg
#  extracting: data/img_align_celeba/198155.jpg
#  extracting: data/img_align_celeba/198156.jpg
#  extracting: data/img_align_celeba/198157.jpg
#  extracting: data/img_align_celeba/198158.jpg
#  extracting: data/img_align_celeba/198159.jpg
#  extracting: data/img_align_celeba/198160.jpg
#  extracting: data/img_align_celeba/198161.jpg
#  extracting: data/img_align_celeba/198162.jpg
#  extracting: data/img_align_celeba/198163.jpg
#  extracting: data/img_align_celeba/198164.jpg
#  extracting: data/img_align_celeba/198165.jpg
#  extracting: data/img_align_celeba/198166.jpg
#  extracting: data/img_align_celeba/198167.jpg
#  extracting: data/img_align_celeba/198168.jpg
#  extracting: data/img_align_celeba/198169.jpg
#  extracting: data/img_align_celeba/198170.jpg
#  extracting: data/img_align_celeba/198171.jpg
#  extracting: data/img_align_celeba/198172.jpg
#  extracting: data/img_align_celeba/198173.jpg
#  extracting: data/img_align_celeba/198174.jpg
#  extracting: data/img_align_celeba/198175.jpg
#  extracting: data/img_align_celeba/198176.jpg
#  extracting: data/img_align_celeba/198177.jpg
#  extracting: data/img_align_celeba/198178.jpg
#  extracting: data/img_align_celeba/198179.jpg
#  extracting: data/img_align_celeba/198180.jpg
#  extracting: data/img_align_celeba/198181.jpg
#  extracting: data/img_align_celeba/198182.jpg
#  extracting: data/img_align_celeba/198183.jpg
#  extracting: data/img_align_celeba/198184.jpg
#  extracting: data/img_align_celeba/198185.jpg
#  extracting: data/img_align_celeba/198186.jpg
#  extracting: data/img_align_celeba/198187.jpg
#  extracting: data/img_align_celeba/198188.jpg
#  extracting: data/img_align_celeba/198189.jpg
#  extracting: data/img_align_celeba/198190.jpg
#  extracting: data/img_align_celeba/198191.jpg
#  extracting: data/img_align_celeba/198192.jpg
#  extracting: data/img_align_celeba/198193.jpg
#  extracting: data/img_align_celeba/198194.jpg
#  extracting: data/img_align_celeba/198195.jpg
#  extracting: data/img_align_celeba/198196.jpg
#  extracting: data/img_align_celeba/198197.jpg
#  extracting: data/img_align_celeba/198198.jpg
#  extracting: data/img_align_celeba/198199.jpg
#  extracting: data/img_align_celeba/198200.jpg
#  extracting: data/img_align_celeba/198201.jpg
#  extracting: data/img_align_celeba/198202.jpg
#  extracting: data/img_align_celeba/198203.jpg
#  extracting: data/img_align_celeba/198204.jpg
#  extracting: data/img_align_celeba/198205.jpg
#  extracting: data/img_align_celeba/198206.jpg
#  extracting: data/img_align_celeba/198207.jpg
#  extracting: data/img_align_celeba/198208.jpg
#  extracting: data/img_align_celeba/198209.jpg
#  extracting: data/img_align_celeba/198210.jpg
#  extracting: data/img_align_celeba/198211.jpg
#  extracting: data/img_align_celeba/198212.jpg
#  extracting: data/img_align_celeba/198213.jpg
#  extracting: data/img_align_celeba/198214.jpg
#  extracting: data/img_align_celeba/198215.jpg
#  extracting: data/img_align_celeba/198216.jpg
#  extracting: data/img_align_celeba/198217.jpg
#  extracting: data/img_align_celeba/198218.jpg
#  extracting: data/img_align_celeba/198219.jpg
#  extracting: data/img_align_celeba/198220.jpg
#  extracting: data/img_align_celeba/198221.jpg
#  extracting: data/img_align_celeba/198222.jpg
#  extracting: data/img_align_celeba/198223.jpg
#  extracting: data/img_align_celeba/198224.jpg
#  extracting: data/img_align_celeba/198225.jpg
#  extracting: data/img_align_celeba/198226.jpg
#  extracting: data/img_align_celeba/198227.jpg
#  extracting: data/img_align_celeba/198228.jpg
#  extracting: data/img_align_celeba/198229.jpg
#  extracting: data/img_align_celeba/198230.jpg
#  extracting: data/img_align_celeba/198231.jpg
#  extracting: data/img_align_celeba/198232.jpg
#  extracting: data/img_align_celeba/198233.jpg
#  extracting: data/img_align_celeba/198234.jpg
#  extracting: data/img_align_celeba/198235.jpg
#  extracting: data/img_align_celeba/198236.jpg
#  extracting: data/img_align_celeba/198237.jpg
#  extracting: data/img_align_celeba/198238.jpg
#  extracting: data/img_align_celeba/198239.jpg
#  extracting: data/img_align_celeba/198240.jpg
#  extracting: data/img_align_celeba/198241.jpg
#  extracting: data/img_align_celeba/198242.jpg
#  extracting: data/img_align_celeba/198243.jpg
#  extracting: data/img_align_celeba/198244.jpg
#  extracting: data/img_align_celeba/198245.jpg
#  extracting: data/img_align_celeba/198246.jpg
#  extracting: data/img_align_celeba/198247.jpg
#  extracting: data/img_align_celeba/198248.jpg
#  extracting: data/img_align_celeba/198249.jpg
#  extracting: data/img_align_celeba/198250.jpg
#  extracting: data/img_align_celeba/198251.jpg
#  extracting: data/img_align_celeba/198252.jpg
#  extracting: data/img_align_celeba/198253.jpg
#  extracting: data/img_align_celeba/198254.jpg
#  extracting: data/img_align_celeba/198255.jpg
#  extracting: data/img_align_celeba/198256.jpg
#  extracting: data/img_align_celeba/198257.jpg
#  extracting: data/img_align_celeba/198258.jpg
#  extracting: data/img_align_celeba/198259.jpg
#  extracting: data/img_align_celeba/198260.jpg
#  extracting: data/img_align_celeba/198261.jpg
#  extracting: data/img_align_celeba/198262.jpg
#  extracting: data/img_align_celeba/198263.jpg
#  extracting: data/img_align_celeba/198264.jpg
#  extracting: data/img_align_celeba/198265.jpg
#  extracting: data/img_align_celeba/198266.jpg
#  extracting: data/img_align_celeba/198267.jpg
#  extracting: data/img_align_celeba/198268.jpg
#  extracting: data/img_align_celeba/198269.jpg
#  extracting: data/img_align_celeba/198270.jpg
#  extracting: data/img_align_celeba/198271.jpg
#  extracting: data/img_align_celeba/198272.jpg
#  extracting: data/img_align_celeba/198273.jpg
#  extracting: data/img_align_celeba/198274.jpg
#  extracting: data/img_align_celeba/198275.jpg
#  extracting: data/img_align_celeba/198276.jpg
#  extracting: data/img_align_celeba/198277.jpg
#  extracting: data/img_align_celeba/198278.jpg
#  extracting: data/img_align_celeba/198279.jpg
#  extracting: data/img_align_celeba/198280.jpg
#  extracting: data/img_align_celeba/198281.jpg
#  extracting: data/img_align_celeba/198282.jpg
#  extracting: data/img_align_celeba/198283.jpg
#  extracting: data/img_align_celeba/198284.jpg
#  extracting: data/img_align_celeba/198285.jpg
#  extracting: data/img_align_celeba/198286.jpg
#  extracting: data/img_align_celeba/198287.jpg
#  extracting: data/img_align_celeba/198288.jpg
#  extracting: data/img_align_celeba/198289.jpg
#  extracting: data/img_align_celeba/198290.jpg
#  extracting: data/img_align_celeba/198291.jpg
#  extracting: data/img_align_celeba/198292.jpg
#  extracting: data/img_align_celeba/198293.jpg
#  extracting: data/img_align_celeba/198294.jpg
#  extracting: data/img_align_celeba/198295.jpg
#  extracting: data/img_align_celeba/198296.jpg
#  extracting: data/img_align_celeba/198297.jpg
#  extracting: data/img_align_celeba/198298.jpg
#  extracting: data/img_align_celeba/198299.jpg
#  extracting: data/img_align_celeba/198300.jpg
#  extracting: data/img_align_celeba/198301.jpg
#  extracting: data/img_align_celeba/198302.jpg
#  extracting: data/img_align_celeba/198303.jpg
#  extracting: data/img_align_celeba/198304.jpg
#  extracting: data/img_align_celeba/198305.jpg
#  extracting: data/img_align_celeba/198306.jpg
#  extracting: data/img_align_celeba/198307.jpg
#  extracting: data/img_align_celeba/198308.jpg
#  extracting: data/img_align_celeba/198309.jpg
#  extracting: data/img_align_celeba/198310.jpg
#  extracting: data/img_align_celeba/198311.jpg
#  extracting: data/img_align_celeba/198312.jpg
#  extracting: data/img_align_celeba/198313.jpg
#  extracting: data/img_align_celeba/198314.jpg
#  extracting: data/img_align_celeba/198315.jpg
#  extracting: data/img_align_celeba/198316.jpg
#  extracting: data/img_align_celeba/198317.jpg
#  extracting: data/img_align_celeba/198318.jpg
#  extracting: data/img_align_celeba/198319.jpg
#  extracting: data/img_align_celeba/198320.jpg
#  extracting: data/img_align_celeba/198321.jpg
#  extracting: data/img_align_celeba/198322.jpg
#  extracting: data/img_align_celeba/198323.jpg
#  extracting: data/img_align_celeba/198324.jpg
#  extracting: data/img_align_celeba/198325.jpg
#  extracting: data/img_align_celeba/198326.jpg
#  extracting: data/img_align_celeba/198327.jpg
#  extracting: data/img_align_celeba/198328.jpg
#  extracting: data/img_align_celeba/198329.jpg
#  extracting: data/img_align_celeba/198330.jpg
#  extracting: data/img_align_celeba/198331.jpg
#  extracting: data/img_align_celeba/198332.jpg
#  extracting: data/img_align_celeba/198333.jpg
#  extracting: data/img_align_celeba/198334.jpg
#  extracting: data/img_align_celeba/198335.jpg
#  extracting: data/img_align_celeba/198336.jpg
#  extracting: data/img_align_celeba/198337.jpg
#  extracting: data/img_align_celeba/198338.jpg
#  extracting: data/img_align_celeba/198339.jpg
#  extracting: data/img_align_celeba/198340.jpg
#  extracting: data/img_align_celeba/198341.jpg
#  extracting: data/img_align_celeba/198342.jpg
#  extracting: data/img_align_celeba/198343.jpg
#  extracting: data/img_align_celeba/198344.jpg
#  extracting: data/img_align_celeba/198345.jpg
#  extracting: data/img_align_celeba/198346.jpg
#  extracting: data/img_align_celeba/198347.jpg
#  extracting: data/img_align_celeba/198348.jpg
#  extracting: data/img_align_celeba/198349.jpg
#  extracting: data/img_align_celeba/198350.jpg
#  extracting: data/img_align_celeba/198351.jpg
#  extracting: data/img_align_celeba/198352.jpg
#  extracting: data/img_align_celeba/198353.jpg
#  extracting: data/img_align_celeba/198354.jpg
#  extracting: data/img_align_celeba/198355.jpg
#  extracting: data/img_align_celeba/198356.jpg
#  extracting: data/img_align_celeba/198357.jpg
#  extracting: data/img_align_celeba/198358.jpg
#  extracting: data/img_align_celeba/198359.jpg
#  extracting: data/img_align_celeba/198360.jpg
#  extracting: data/img_align_celeba/198361.jpg
#  extracting: data/img_align_celeba/198362.jpg
#  extracting: data/img_align_celeba/198363.jpg
#  extracting: data/img_align_celeba/198364.jpg
#  extracting: data/img_align_celeba/198365.jpg
#  extracting: data/img_align_celeba/198366.jpg
#  extracting: data/img_align_celeba/198367.jpg
#  extracting: data/img_align_celeba/198368.jpg
#  extracting: data/img_align_celeba/198369.jpg
#  extracting: data/img_align_celeba/198370.jpg
#  extracting: data/img_align_celeba/198371.jpg
#  extracting: data/img_align_celeba/198372.jpg
#  extracting: data/img_align_celeba/198373.jpg
#  extracting: data/img_align_celeba/198374.jpg
#  extracting: data/img_align_celeba/198375.jpg
#  extracting: data/img_align_celeba/198376.jpg
#  extracting: data/img_align_celeba/198377.jpg
#  extracting: data/img_align_celeba/198378.jpg
#  extracting: data/img_align_celeba/198379.jpg
#  extracting: data/img_align_celeba/198380.jpg
#  extracting: data/img_align_celeba/198381.jpg
#  extracting: data/img_align_celeba/198382.jpg
#  extracting: data/img_align_celeba/198383.jpg
#  extracting: data/img_align_celeba/198384.jpg
#  extracting: data/img_align_celeba/198385.jpg
#  extracting: data/img_align_celeba/198386.jpg
#  extracting: data/img_align_celeba/198387.jpg
#  extracting: data/img_align_celeba/198388.jpg
#  extracting: data/img_align_celeba/198389.jpg
#  extracting: data/img_align_celeba/198390.jpg
#  extracting: data/img_align_celeba/198391.jpg
#  extracting: data/img_align_celeba/198392.jpg
#  extracting: data/img_align_celeba/198393.jpg
#  extracting: data/img_align_celeba/198394.jpg
#  extracting: data/img_align_celeba/198395.jpg
#  extracting: data/img_align_celeba/198396.jpg
#  extracting: data/img_align_celeba/198397.jpg
#  extracting: data/img_align_celeba/198398.jpg
#  extracting: data/img_align_celeba/198399.jpg
#  extracting: data/img_align_celeba/198400.jpg
#  extracting: data/img_align_celeba/198401.jpg
#  extracting: data/img_align_celeba/198402.jpg
#  extracting: data/img_align_celeba/198403.jpg
#  extracting: data/img_align_celeba/198404.jpg
#  extracting: data/img_align_celeba/198405.jpg
#  extracting: data/img_align_celeba/198406.jpg
#  extracting: data/img_align_celeba/198407.jpg
#  extracting: data/img_align_celeba/198408.jpg
#  extracting: data/img_align_celeba/198409.jpg
#  extracting: data/img_align_celeba/198410.jpg
#  extracting: data/img_align_celeba/198411.jpg
#  extracting: data/img_align_celeba/198412.jpg
#  extracting: data/img_align_celeba/198413.jpg
#  extracting: data/img_align_celeba/198414.jpg
#  extracting: data/img_align_celeba/198415.jpg
#  extracting: data/img_align_celeba/198416.jpg
#  extracting: data/img_align_celeba/198417.jpg
#  extracting: data/img_align_celeba/198418.jpg
#  extracting: data/img_align_celeba/198419.jpg
#  extracting: data/img_align_celeba/198420.jpg
#  extracting: data/img_align_celeba/198421.jpg
#  extracting: data/img_align_celeba/198422.jpg
#  extracting: data/img_align_celeba/198423.jpg
#  extracting: data/img_align_celeba/198424.jpg
#  extracting: data/img_align_celeba/198425.jpg
#  extracting: data/img_align_celeba/198426.jpg
#  extracting: data/img_align_celeba/198427.jpg
#  extracting: data/img_align_celeba/198428.jpg
#  extracting: data/img_align_celeba/198429.jpg
#  extracting: data/img_align_celeba/198430.jpg
#  extracting: data/img_align_celeba/198431.jpg
#  extracting: data/img_align_celeba/198432.jpg
#  extracting: data/img_align_celeba/198433.jpg
#  extracting: data/img_align_celeba/198434.jpg
#  extracting: data/img_align_celeba/198435.jpg
#  extracting: data/img_align_celeba/198436.jpg
#  extracting: data/img_align_celeba/198437.jpg
#  extracting: data/img_align_celeba/198438.jpg
#  extracting: data/img_align_celeba/198439.jpg
#  extracting: data/img_align_celeba/198440.jpg
#  extracting: data/img_align_celeba/198441.jpg
#  extracting: data/img_align_celeba/198442.jpg
#  extracting: data/img_align_celeba/198443.jpg
#  extracting: data/img_align_celeba/198444.jpg
#  extracting: data/img_align_celeba/198445.jpg
#  extracting: data/img_align_celeba/198446.jpg
#  extracting: data/img_align_celeba/198447.jpg
#  extracting: data/img_align_celeba/198448.jpg
#  extracting: data/img_align_celeba/198449.jpg
#  extracting: data/img_align_celeba/198450.jpg
#  extracting: data/img_align_celeba/198451.jpg
#  extracting: data/img_align_celeba/198452.jpg
#  extracting: data/img_align_celeba/198453.jpg
#  extracting: data/img_align_celeba/198454.jpg
#  extracting: data/img_align_celeba/198455.jpg
#  extracting: data/img_align_celeba/198456.jpg
#  extracting: data/img_align_celeba/198457.jpg
#  extracting: data/img_align_celeba/198458.jpg
#  extracting: data/img_align_celeba/198459.jpg
#  extracting: data/img_align_celeba/198460.jpg
#  extracting: data/img_align_celeba/198461.jpg
#  extracting: data/img_align_celeba/198462.jpg
#  extracting: data/img_align_celeba/198463.jpg
#  extracting: data/img_align_celeba/198464.jpg
#  extracting: data/img_align_celeba/198465.jpg
#  extracting: data/img_align_celeba/198466.jpg
#  extracting: data/img_align_celeba/198467.jpg
#  extracting: data/img_align_celeba/198468.jpg
#  extracting: data/img_align_celeba/198469.jpg
#  extracting: data/img_align_celeba/198470.jpg
#  extracting: data/img_align_celeba/198471.jpg
#  extracting: data/img_align_celeba/198472.jpg
#  extracting: data/img_align_celeba/198473.jpg
#  extracting: data/img_align_celeba/198474.jpg
#  extracting: data/img_align_celeba/198475.jpg
#  extracting: data/img_align_celeba/198476.jpg
#  extracting: data/img_align_celeba/198477.jpg
#  extracting: data/img_align_celeba/198478.jpg
#  extracting: data/img_align_celeba/198479.jpg
#  extracting: data/img_align_celeba/198480.jpg
#  extracting: data/img_align_celeba/198481.jpg
#  extracting: data/img_align_celeba/198482.jpg
#  extracting: data/img_align_celeba/198483.jpg
#  extracting: data/img_align_celeba/198484.jpg
#  extracting: data/img_align_celeba/198485.jpg
#  extracting: data/img_align_celeba/198486.jpg
#  extracting: data/img_align_celeba/198487.jpg
#  extracting: data/img_align_celeba/198488.jpg
#  extracting: data/img_align_celeba/198489.jpg
#  extracting: data/img_align_celeba/198490.jpg
#  extracting: data/img_align_celeba/198491.jpg
#  extracting: data/img_align_celeba/198492.jpg
#  extracting: data/img_align_celeba/198493.jpg
#  extracting: data/img_align_celeba/198494.jpg
#  extracting: data/img_align_celeba/198495.jpg
#  extracting: data/img_align_celeba/198496.jpg
#  extracting: data/img_align_celeba/198497.jpg
#  extracting: data/img_align_celeba/198498.jpg
#  extracting: data/img_align_celeba/198499.jpg
#  extracting: data/img_align_celeba/198500.jpg
#  extracting: data/img_align_celeba/198501.jpg
#  extracting: data/img_align_celeba/198502.jpg
#  extracting: data/img_align_celeba/198503.jpg
#  extracting: data/img_align_celeba/198504.jpg
#  extracting: data/img_align_celeba/198505.jpg
#  extracting: data/img_align_celeba/198506.jpg
#  extracting: data/img_align_celeba/198507.jpg
#  extracting: data/img_align_celeba/198508.jpg
#  extracting: data/img_align_celeba/198509.jpg
#  extracting: data/img_align_celeba/198510.jpg
#  extracting: data/img_align_celeba/198511.jpg
#  extracting: data/img_align_celeba/198512.jpg
#  extracting: data/img_align_celeba/198513.jpg
#  extracting: data/img_align_celeba/198514.jpg
#  extracting: data/img_align_celeba/198515.jpg
#  extracting: data/img_align_celeba/198516.jpg
#  extracting: data/img_align_celeba/198517.jpg
#  extracting: data/img_align_celeba/198518.jpg
#  extracting: data/img_align_celeba/198519.jpg
#  extracting: data/img_align_celeba/198520.jpg
#  extracting: data/img_align_celeba/198521.jpg
#  extracting: data/img_align_celeba/198522.jpg
#  extracting: data/img_align_celeba/198523.jpg
#  extracting: data/img_align_celeba/198524.jpg
#  extracting: data/img_align_celeba/198525.jpg
#  extracting: data/img_align_celeba/198526.jpg
#  extracting: data/img_align_celeba/198527.jpg
#  extracting: data/img_align_celeba/198528.jpg
#  extracting: data/img_align_celeba/198529.jpg
#  extracting: data/img_align_celeba/198530.jpg
#  extracting: data/img_align_celeba/198531.jpg
#  extracting: data/img_align_celeba/198532.jpg
#  extracting: data/img_align_celeba/198533.jpg
#  extracting: data/img_align_celeba/198534.jpg
#  extracting: data/img_align_celeba/198535.jpg
#  extracting: data/img_align_celeba/198536.jpg
#  extracting: data/img_align_celeba/198537.jpg
#  extracting: data/img_align_celeba/198538.jpg
#  extracting: data/img_align_celeba/198539.jpg
#  extracting: data/img_align_celeba/198540.jpg
#  extracting: data/img_align_celeba/198541.jpg
#  extracting: data/img_align_celeba/198542.jpg
#  extracting: data/img_align_celeba/198543.jpg
#  extracting: data/img_align_celeba/198544.jpg
#  extracting: data/img_align_celeba/198545.jpg
#  extracting: data/img_align_celeba/198546.jpg
#  extracting: data/img_align_celeba/198547.jpg
#  extracting: data/img_align_celeba/198548.jpg
#  extracting: data/img_align_celeba/198549.jpg
#  extracting: data/img_align_celeba/198550.jpg
#  extracting: data/img_align_celeba/198551.jpg
#  extracting: data/img_align_celeba/198552.jpg
#  extracting: data/img_align_celeba/198553.jpg
#  extracting: data/img_align_celeba/198554.jpg
#  extracting: data/img_align_celeba/198555.jpg
#  extracting: data/img_align_celeba/198556.jpg
#  extracting: data/img_align_celeba/198557.jpg
#  extracting: data/img_align_celeba/198558.jpg
#  extracting: data/img_align_celeba/198559.jpg
#  extracting: data/img_align_celeba/198560.jpg
#  extracting: data/img_align_celeba/198561.jpg
#  extracting: data/img_align_celeba/198562.jpg
#  extracting: data/img_align_celeba/198563.jpg
#  extracting: data/img_align_celeba/198564.jpg
#  extracting: data/img_align_celeba/198565.jpg
#  extracting: data/img_align_celeba/198566.jpg
#  extracting: data/img_align_celeba/198567.jpg
#  extracting: data/img_align_celeba/198568.jpg
#  extracting: data/img_align_celeba/198569.jpg
#  extracting: data/img_align_celeba/198570.jpg
#  extracting: data/img_align_celeba/198571.jpg
#  extracting: data/img_align_celeba/198572.jpg
#  extracting: data/img_align_celeba/198573.jpg
#  extracting: data/img_align_celeba/198574.jpg
#  extracting: data/img_align_celeba/198575.jpg
#  extracting: data/img_align_celeba/198576.jpg
#  extracting: data/img_align_celeba/198577.jpg
#  extracting: data/img_align_celeba/198578.jpg
#  extracting: data/img_align_celeba/198579.jpg
#  extracting: data/img_align_celeba/198580.jpg
#  extracting: data/img_align_celeba/198581.jpg
#  extracting: data/img_align_celeba/198582.jpg
#  extracting: data/img_align_celeba/198583.jpg
#  extracting: data/img_align_celeba/198584.jpg
#  extracting: data/img_align_celeba/198585.jpg
#  extracting: data/img_align_celeba/198586.jpg
#  extracting: data/img_align_celeba/198587.jpg
#  extracting: data/img_align_celeba/198588.jpg
#  extracting: data/img_align_celeba/198589.jpg
#  extracting: data/img_align_celeba/198590.jpg
#  extracting: data/img_align_celeba/198591.jpg
#  extracting: data/img_align_celeba/198592.jpg
#  extracting: data/img_align_celeba/198593.jpg
#  extracting: data/img_align_celeba/198594.jpg
#  extracting: data/img_align_celeba/198595.jpg
#  extracting: data/img_align_celeba/198596.jpg
#  extracting: data/img_align_celeba/198597.jpg
# ...
#  extracting: data/img_align_celeba/202267.jpg
#  extracting: data/img_align_celeba/202268.jpg
#  extracting: data/img_align_celeba/202269.jpg
#  extracting: data/img_align_celeba/202270.jpg
#  extracting: data/img_align_celeba/202271.jpg
#  extracting: data/img_align_celeba/202272.jpg
#  extracting: data/img_align_celeba/202273.jpg
#  extracting: data/img_align_celeba/202274.jpg
#  extracting: data/img_align_celeba/202275.jpg
#  extracting: data/img_align_celeba/202276.jpg
#  extracting: data/img_align_celeba/202277.jpg
#  extracting: data/img_align_celeba/202278.jpg
#  extracting: data/img_align_celeba/202279.jpg
#  extracting: data/img_align_celeba/202280.jpg
#  extracting: data/img_align_celeba/202281.jpg
#  extracting: data/img_align_celeba/202282.jpg
#  extracting: data/img_align_celeba/202283.jpg
#  extracting: data/img_align_celeba/202284.jpg
#  extracting: data/img_align_celeba/202285.jpg
#  extracting: data/img_align_celeba/202286.jpg
#  extracting: data/img_align_celeba/202287.jpg
#  extracting: data/img_align_celeba/202288.jpg
#  extracting: data/img_align_celeba/202289.jpg
#  extracting: data/img_align_celeba/202290.jpg
#  extracting: data/img_align_celeba/202291.jpg
#  extracting: data/img_align_celeba/202292.jpg
#  extracting: data/img_align_celeba/202293.jpg
#  extracting: data/img_align_celeba/202294.jpg
#  extracting: data/img_align_celeba/202295.jpg
#  extracting: data/img_align_celeba/202296.jpg
#  extracting: data/img_align_celeba/202297.jpg
#  extracting: data/img_align_celeba/202298.jpg
#  extracting: data/img_align_celeba/202299.jpg
#  extracting: data/img_align_celeba/202300.jpg
#  extracting: data/img_align_celeba/202301.jpg
#  extracting: data/img_align_celeba/202302.jpg
#  extracting: data/img_align_celeba/202303.jpg
#  extracting: data/img_align_celeba/202304.jpg
#  extracting: data/img_align_celeba/202305.jpg
#  extracting: data/img_align_celeba/202306.jpg
#  extracting: data/img_align_celeba/202307.jpg
#  extracting: data/img_align_celeba/202308.jpg
#  extracting: data/img_align_celeba/202309.jpg
#  extracting: data/img_align_celeba/202310.jpg
#  extracting: data/img_align_celeba/202311.jpg
#  extracting: data/img_align_celeba/202312.jpg
#  extracting: data/img_align_celeba/202313.jpg
#  extracting: data/img_align_celeba/202314.jpg
#  extracting: data/img_align_celeba/202315.jpg
#  extracting: data/img_align_celeba/202316.jpg
#  extracting: data/img_align_celeba/202317.jpg
#  extracting: data/img_align_celeba/202318.jpg
#  extracting: data/img_align_celeba/202319.jpg
#  extracting: data/img_align_celeba/202320.jpg
#  extracting: data/img_align_celeba/202321.jpg
#  extracting: data/img_align_celeba/202322.jpg
#  extracting: data/img_align_celeba/202323.jpg
#  extracting: data/img_align_celeba/202324.jpg
#  extracting: data/img_align_celeba/202325.jpg
#  extracting: data/img_align_celeba/202326.jpg
#  extracting: data/img_align_celeba/202327.jpg
#  extracting: data/img_align_celeba/202328.jpg
#  extracting: data/img_align_celeba/202329.jpg
#  extracting: data/img_align_celeba/202330.jpg
#  extracting: data/img_align_celeba/202331.jpg
#  extracting: data/img_align_celeba/202332.jpg
#  extracting: data/img_align_celeba/202333.jpg
#  extracting: data/img_align_celeba/202334.jpg
#  extracting: data/img_align_celeba/202335.jpg
#  extracting: data/img_align_celeba/202336.jpg
#  extracting: data/img_align_celeba/202337.jpg
#  extracting: data/img_align_celeba/202338.jpg
#  extracting: data/img_align_celeba/202339.jpg
#  extracting: data/img_align_celeba/202340.jpg
#  extracting: data/img_align_celeba/202341.jpg
#  extracting: data/img_align_celeba/202342.jpg
#  extracting: data/img_align_celeba/202343.jpg
#  extracting: data/img_align_celeba/202344.jpg
#  extracting: data/img_align_celeba/202345.jpg
#  extracting: data/img_align_celeba/202346.jpg
#  extracting: data/img_align_celeba/202347.jpg
#  extracting: data/img_align_celeba/202348.jpg
#  extracting: data/img_align_celeba/202349.jpg
#  extracting: data/img_align_celeba/202350.jpg
#  extracting: data/img_align_celeba/202351.jpg
#  extracting: data/img_align_celeba/202352.jpg
#  extracting: data/img_align_celeba/202353.jpg
#  extracting: data/img_align_celeba/202354.jpg
#  extracting: data/img_align_celeba/202355.jpg
#  extracting: data/img_align_celeba/202356.jpg
#  extracting: data/img_align_celeba/202357.jpg
#  extracting: data/img_align_celeba/202358.jpg
#  extracting: data/img_align_celeba/202359.jpg
#  extracting: data/img_align_celeba/202360.jpg
#  extracting: data/img_align_celeba/202361.jpg
#  extracting: data/img_align_celeba/202362.jpg
#  extracting: data/img_align_celeba/202363.jpg
#  extracting: data/img_align_celeba/202364.jpg
#  extracting: data/img_align_celeba/202365.jpg
#  extracting: data/img_align_celeba/202366.jpg
#  extracting: data/img_align_celeba/202367.jpg
#  extracting: data/img_align_celeba/202368.jpg
#  extracting: data/img_align_celeba/202369.jpg
#  extracting: data/img_align_celeba/202370.jpg
#  extracting: data/img_align_celeba/202371.jpg
#  extracting: data/img_align_celeba/202372.jpg
#  extracting: data/img_align_celeba/202373.jpg
#  extracting: data/img_align_celeba/202374.jpg
#  extracting: data/img_align_celeba/202375.jpg
#  extracting: data/img_align_celeba/202376.jpg
#  extracting: data/img_align_celeba/202377.jpg
#  extracting: data/img_align_celeba/202378.jpg
#  extracting: data/img_align_celeba/202379.jpg
#  extracting: data/img_align_celeba/202380.jpg
#  extracting: data/img_align_celeba/202381.jpg
#  extracting: data/img_align_celeba/202382.jpg
#  extracting: data/img_align_celeba/202383.jpg
#  extracting: data/img_align_celeba/202384.jpg
#  extracting: data/img_align_celeba/202385.jpg
#  extracting: data/img_align_celeba/202386.jpg
#  extracting: data/img_align_celeba/202387.jpg
#  extracting: data/img_align_celeba/202388.jpg
#  extracting: data/img_align_celeba/202389.jpg
#  extracting: data/img_align_celeba/202390.jpg
#  extracting: data/img_align_celeba/202391.jpg
#  extracting: data/img_align_celeba/202392.jpg
#  extracting: data/img_align_celeba/202393.jpg
#  extracting: data/img_align_celeba/202394.jpg
#  extracting: data/img_align_celeba/202395.jpg
#  extracting: data/img_align_celeba/202396.jpg
#  extracting: data/img_align_celeba/202397.jpg
#  extracting: data/img_align_celeba/202398.jpg
#  extracting: data/img_align_celeba/202399.jpg
#  extracting: data/img_align_celeba/202400.jpg
#  extracting: data/img_align_celeba/202401.jpg
#  extracting: data/img_align_celeba/202402.jpg
#  extracting: data/img_align_celeba/202403.jpg
#  extracting: data/img_align_celeba/202404.jpg
#  extracting: data/img_align_celeba/202405.jpg
#  extracting: data/img_align_celeba/202406.jpg
#  extracting: data/img_align_celeba/202407.jpg
#  extracting: data/img_align_celeba/202408.jpg
#  extracting: data/img_align_celeba/202409.jpg
#  extracting: data/img_align_celeba/202410.jpg
#  extracting: data/img_align_celeba/202411.jpg
#  extracting: data/img_align_celeba/202412.jpg
#  extracting: data/img_align_celeba/202413.jpg
#  extracting: data/img_align_celeba/202414.jpg
#  extracting: data/img_align_celeba/202415.jpg
#  extracting: data/img_align_celeba/202416.jpg
#  extracting: data/img_align_celeba/202417.jpg
#  extracting: data/img_align_celeba/202418.jpg
#  extracting: data/img_align_celeba/202419.jpg
#  extracting: data/img_align_celeba/202420.jpg
#  extracting: data/img_align_celeba/202421.jpg
#  extracting: data/img_align_celeba/202422.jpg
#  extracting: data/img_align_celeba/202423.jpg
#  extracting: data/img_align_celeba/202424.jpg
#  extracting: data/img_align_celeba/202425.jpg
#  extracting: data/img_align_celeba/202426.jpg
#  extracting: data/img_align_celeba/202427.jpg
#  extracting: data/img_align_celeba/202428.jpg
#  extracting: data/img_align_celeba/202429.jpg
#  extracting: data/img_align_celeba/202430.jpg
#  extracting: data/img_align_celeba/202431.jpg
#  extracting: data/img_align_celeba/202432.jpg
#  extracting: data/img_align_celeba/202433.jpg
#  extracting: data/img_align_celeba/202434.jpg
#  extracting: data/img_align_celeba/202435.jpg
#  extracting: data/img_align_celeba/202436.jpg
#  extracting: data/img_align_celeba/202437.jpg
#  extracting: data/img_align_celeba/202438.jpg
#  extracting: data/img_align_celeba/202439.jpg
#  extracting: data/img_align_celeba/202440.jpg
#  extracting: data/img_align_celeba/202441.jpg
#  extracting: data/img_align_celeba/202442.jpg
#  extracting: data/img_align_celeba/202443.jpg
#  extracting: data/img_align_celeba/202444.jpg
#  extracting: data/img_align_celeba/202445.jpg
#  extracting: data/img_align_celeba/202446.jpg
#  extracting: data/img_align_celeba/202447.jpg
#  extracting: data/img_align_celeba/202448.jpg
#  extracting: data/img_align_celeba/202449.jpg
#  extracting: data/img_align_celeba/202450.jpg
#  extracting: data/img_align_celeba/202451.jpg
#  extracting: data/img_align_celeba/202452.jpg
#  extracting: data/img_align_celeba/202453.jpg
#  extracting: data/img_align_celeba/202454.jpg
#  extracting: data/img_align_celeba/202455.jpg
#  extracting: data/img_align_celeba/202456.jpg
#  extracting: data/img_align_celeba/202457.jpg
#  extracting: data/img_align_celeba/202458.jpg
#  extracting: data/img_align_celeba/202459.jpg
#  extracting: data/img_align_celeba/202460.jpg
#  extracting: data/img_align_celeba/202461.jpg
#  extracting: data/img_align_celeba/202462.jpg
#  extracting: data/img_align_celeba/202463.jpg
#  extracting: data/img_align_celeba/202464.jpg
#  extracting: data/img_align_celeba/202465.jpg
#  extracting: data/img_align_celeba/202466.jpg
#  extracting: data/img_align_celeba/202467.jpg
#  extracting: data/img_align_celeba/202468.jpg
#  extracting: data/img_align_celeba/202469.jpg
#  extracting: data/img_align_celeba/202470.jpg
#  extracting: data/img_align_celeba/202471.jpg
#  extracting: data/img_align_celeba/202472.jpg
#  extracting: data/img_align_celeba/202473.jpg
#  extracting: data/img_align_celeba/202474.jpg
#  extracting: data/img_align_celeba/202475.jpg
#  extracting: data/img_align_celeba/202476.jpg
#  extracting: data/img_align_celeba/202477.jpg
#  extracting: data/img_align_celeba/202478.jpg
#  extracting: data/img_align_celeba/202479.jpg
#  extracting: data/img_align_celeba/202480.jpg
#  extracting: data/img_align_celeba/202481.jpg
#  extracting: data/img_align_celeba/202482.jpg
#  extracting: data/img_align_celeba/202483.jpg
#  extracting: data/img_align_celeba/202484.jpg
#  extracting: data/img_align_celeba/202485.jpg
#  extracting: data/img_align_celeba/202486.jpg
#  extracting: data/img_align_celeba/202487.jpg
#  extracting: data/img_align_celeba/202488.jpg
#  extracting: data/img_align_celeba/202489.jpg
#  extracting: data/img_align_celeba/202490.jpg
#  extracting: data/img_align_celeba/202491.jpg
#  extracting: data/img_align_celeba/202492.jpg
#  extracting: data/img_align_celeba/202493.jpg
#  extracting: data/img_align_celeba/202494.jpg
#  extracting: data/img_align_celeba/202495.jpg
#  extracting: data/img_align_celeba/202496.jpg
#  extracting: data/img_align_celeba/202497.jpg
#  extracting: data/img_align_celeba/202498.jpg
#  extracting: data/img_align_celeba/202499.jpg
#  extracting: data/img_align_celeba/202500.jpg
#  extracting: data/img_align_celeba/202501.jpg
#  extracting: data/img_align_celeba/202502.jpg
#  extracting: data/img_align_celeba/202503.jpg
#  extracting: data/img_align_celeba/202504.jpg
#  extracting: data/img_align_celeba/202505.jpg
#  extracting: data/img_align_celeba/202506.jpg
#  extracting: data/img_align_celeba/202507.jpg
#  extracting: data/img_align_celeba/202508.jpg
#  extracting: data/img_align_celeba/202509.jpg
#  extracting: data/img_align_celeba/202510.jpg
#  extracting: data/img_align_celeba/202511.jpg
#  extracting: data/img_align_celeba/202512.jpg
#  extracting: data/img_align_celeba/202513.jpg
#  extracting: data/img_align_celeba/202514.jpg
#  extracting: data/img_align_celeba/202515.jpg
#  extracting: data/img_align_celeba/202516.jpg
#  extracting: data/img_align_celeba/202517.jpg
#  extracting: data/img_align_celeba/202518.jpg
#  extracting: data/img_align_celeba/202519.jpg
#  extracting: data/img_align_celeba/202520.jpg
#  extracting: data/img_align_celeba/202521.jpg
#  extracting: data/img_align_celeba/202522.jpg
#  extracting: data/img_align_celeba/202523.jpg
#  extracting: data/img_align_celeba/202524.jpg
#  extracting: data/img_align_celeba/202525.jpg
#  extracting: data/img_align_celeba/202526.jpg
#  extracting: data/img_align_celeba/202527.jpg
#  extracting: data/img_align_celeba/202528.jpg
#  extracting: data/img_align_celeba/202529.jpg
#  extracting: data/img_align_celeba/202530.jpg
#  extracting: data/img_align_celeba/202531.jpg
#  extracting: data/img_align_celeba/202532.jpg
#  extracting: data/img_align_celeba/202533.jpg
#  extracting: data/img_align_celeba/202534.jpg
#  extracting: data/img_align_celeba/202535.jpg
#  extracting: data/img_align_celeba/202536.jpg
#  extracting: data/img_align_celeba/202537.jpg
#  extracting: data/img_align_celeba/202538.jpg
#  extracting: data/img_align_celeba/202539.jpg
#  extracting: data/img_align_celeba/202540.jpg
#  extracting: data/img_align_celeba/202541.jpg
#  extracting: data/img_align_celeba/202542.jpg
#  extracting: data/img_align_celeba/202543.jpg
#  extracting: data/img_align_celeba/202544.jpg
#  extracting: data/img_align_celeba/202545.jpg
#  extracting: data/img_align_celeba/202546.jpg
#  extracting: data/img_align_celeba/202547.jpg
#  extracting: data/img_align_celeba/202548.jpg
#  extracting: data/img_align_celeba/202549.jpg
#  extracting: data/img_align_celeba/202550.jpg
#  extracting: data/img_align_celeba/202551.jpg
#  extracting: data/img_align_celeba/202552.jpg
#  extracting: data/img_align_celeba/202553.jpg
#  extracting: data/img_align_celeba/202554.jpg
#  extracting: data/img_align_celeba/202555.jpg
#  extracting: data/img_align_celeba/202556.jpg
#  extracting: data/img_align_celeba/202557.jpg
#  extracting: data/img_align_celeba/202558.jpg
#  extracting: data/img_align_celeba/202559.jpg
#  extracting: data/img_align_celeba/202560.jpg
#  extracting: data/img_align_celeba/202561.jpg
#  extracting: data/img_align_celeba/202562.jpg
#  extracting: data/img_align_celeba/202563.jpg
#  extracting: data/img_align_celeba/202564.jpg
#  extracting: data/img_align_celeba/202565.jpg
#  extracting: data/img_align_celeba/202566.jpg
#  extracting: data/img_align_celeba/202567.jpg
#  extracting: data/img_align_celeba/202568.jpg
#  extracting: data/img_align_celeba/202569.jpg
#  extracting: data/img_align_celeba/202570.jpg
#  extracting: data/img_align_celeba/202571.jpg
#  extracting: data/img_align_celeba/202572.jpg
#  extracting: data/img_align_celeba/202573.jpg
#  extracting: data/img_align_celeba/202574.jpg
#  extracting: data/img_align_celeba/202575.jpg
#  extracting: data/img_align_celeba/202576.jpg
#  extracting: data/img_align_celeba/202577.jpg
#  extracting: data/img_align_celeba/202578.jpg
#  extracting: data/img_align_celeba/202579.jpg
#  extracting: data/img_align_celeba/202580.jpg
#  extracting: data/img_align_celeba/202581.jpg
#  extracting: data/img_align_celeba/202582.jpg
#  extracting: data/img_align_celeba/202583.jpg
#  extracting: data/img_align_celeba/202584.jpg
#  extracting: data/img_align_celeba/202585.jpg
#  extracting: data/img_align_celeba/202586.jpg
#  extracting: data/img_align_celeba/202587.jpg
#  extracting: data/img_align_celeba/202588.jpg
#  extracting: data/img_align_celeba/202589.jpg
#  extracting: data/img_align_celeba/202590.jpg
#  extracting: data/img_align_celeba/202591.jpg
#  extracting: data/img_align_celeba/202592.jpg
#  extracting: data/img_align_celeba/202593.jpg
#  extracting: data/img_align_celeba/202594.jpg
#  extracting: data/img_align_celeba/202595.jpg
#  extracting: data/img_align_celeba/202596.jpg
#  extracting: data/img_align_celeba/202597.jpg
#  extracting: data/img_align_celeba/202598.jpg
#  extracting: data/img_align_celeba/202599.jpg

# %%
batch_size = 128
lr = 0.0002
train_epoch = 3

img_size = 64

#download the data, and change the filepath

# possible sources for celeba: this AWS link: https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/celeba.zip
celeba_dataset = datasets.ImageFolder(root='/content/data/',
                           transform=transforms.Compose([
                               transforms.Resize(img_size),
                               transforms.CenterCrop(img_size),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))
##### Create the dataloader #####
celeba_train_loader = torch.utils.data.DataLoader(celeba_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# Dataset and DataLoader are abstractions to help us iterate over the data in random order.

# %% [markdown]
# Let's look at a sample:

# %%
ix=140
x, _ = celeba_dataset[ix]
show_imgs(x)

# %% [markdown]
# Feed the image into the discriminator; the output will be the probability the (untrained) discriminator assigns to this sample being real.

# %%
# for one image:
Dscore = D(x.unsqueeze(0))
Dscore
# Out:
# tensor([[[[0.4248]]]], grad_fn=<SigmoidBackward0>)

# %%
# How you can get a batch of images from the dataloader:
xbatch, _ = iter(celeba_train_loader).next()
xbatch.shape
D(xbatch)
D(xbatch).shape
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# torch.Size([128, 1, 1, 1])

# %%
show_imgs(xbatch)

# %% [markdown]
# # 3. Now to train your GAN

# %% [markdown]
# We introduced and defined the generator G, the discriminator D, and the dataloader which will give us minibatches of real data.
#
# To recap the basic idea of the min-max / adversarial game:
# * The Generator and Discriminator have competing objectives, they are "adversaries".
# * The Discriminator wants to assign high probability to real images and low probability to generated (fake) images
# * The Generator wants its generated images to look real, so wants to modify its outputs to get high scores from the Discriminator
# * We will optimize both alternatingly, with SGD steps (as before): optimize $\theta_D$ the weights of $D(x, \theta_D)$, and  $\theta_G$ the weights of $G(z, \theta_G)$.
# * Final goal of the whole min-max game is for the Generator to match the data distribution: $p_G(x) \approx p_{data}(x)$.
#
#
# Now what are the objective functions for each of them? As mentioned in the introduction, the objective for the discriminator is to classify the real images as real, so $D(x) = 1$, and the fake images as fake, so $D(G(z))=0$.
# This is a typical binary classification problem which calls for the binary cross-entropy (BCE) loss, which encourages exactly this solution.
#
# For G we just try to minimize the same loss that D maximizes. See how G appears inside D? This shows how the output of the generator G is passed into the Discriminator to compute the loss.
#
#
# This is the optimization problem:
#
# $$
# \min _{G} \max _{D} V(D, G)=\mathbb{E}_{\boldsymbol{x} \sim p_{\text { data }}(\boldsymbol{x})}[\log D(\boldsymbol{x})]+\mathbb{E}_{\boldsymbol{z} \sim p_{\boldsymbol{z}}(\boldsymbol{z})}[\log (1-D(G(\boldsymbol{z})))]
# $$
#
# We will do a single SGD step alternatingly to maximize D, then minimize G.
# In fact for G we use a modified (non-saturing) loss $-\log D(G(z))$. Different modifications of the loss and the relation to the distance between distributions $p_{data}$ and $p_{G}$ became a topic of research over the last years.
#
# BCE takes care of the log, you won't manually compute any Log values

# %%
G = Generator(128)
D = Discriminator(128)
G = G.cuda()
D = D.cuda()

# Binary Cross Entropy loss
BCE_loss = nn.BCELoss()

# Adam optimizer
G_optimizer = optim.Adam(G.parameters(), lr=lr, betas=(0.5, 0.999))
D_optimizer = optim.Adam(D.parameters(), lr=lr, betas=(0.5, 0.999))
# Train GAN
collect_x_gen = []

# %%
def train(train_loader):
    num_iter = 0
    
    for epoch in range(train_epoch):
        D_losses = []
        G_losses = []
        epoch_start_time = time.time()
        for x_, _ in tqdm(train_loader):
            # train discriminator D
            D.zero_grad()
            mini_batch = x_.size()[0]

            #####
            # create y_real_ and y_fake_ tensors you will use in your BCE loss to push probabilities 
            # in the proper direction
            # y_real_ will be a tensor of all ones, because you want whatever is outputted by the generator
            # to be more likely to be real and you want the discriminator to recognize real images
            # y_fake_ then is a tensor of all zeros, because you want the discriminator to recognize fake images
            #####
            y_real_ = torch.ones(mini_batch)
            y_fake_ = torch.zeros(mini_batch)

            x_, y_real_, y_fake_ = Variable(x_.cuda()), Variable(y_real_.cuda()), Variable(y_fake_.cuda())

            #####
            # pass x_ through the discriminator to get D_result
            # you will need to squeeze() the output before passing it to BCE_loss
            # compute D_real_loss using BCE_loss and the proper y tensor from above
            # you are trying to make the discriminator recognize the real image properly
            #####
            D_result = D(x_).squeeze()
            # pdb.set_trace()
            D_real_loss = BCE_loss(D_result, y_real_)


            #####
            # sample a z vector (remember to view(-1,100,1,1))
            # pass the z vector to the GPU and through your generator
            # this will create G_result
            #####
            z = torch.randn((mini_batch, 100)).view(-1, 100, 1, 1)
            z = Variable(z.cuda())
            G_result = G(z)
            #####
            # pass G_result through the discriminator and get D_result
            # you will need to squeeze() the output of the discriminator
            # compute D_fake_loss for the generated images by using BCE_loss and the proper y_tensor
            # you are trying to make the discriminator recognize the fake image properly
            #####
            D_temp_result = D(G_result).squeeze()

            D_fake_loss = BCE_loss(D_temp_result, y_fake_)

            # pdb.set_trace()

            #####
            # sum D_real_loss and D_fake_loss to get D_train_loss
            # compute the gradients
            # step the optimizer
            #####

            D_train_loss = D_real_loss + D_fake_loss
            # pdb.set_trace()
            D_losses.append(D_train_loss.item())

            D_train_loss.backward()
            D_optimizer.step()

            # train generator G
            G.zero_grad()

            #####
            # sample a z vector (viewed properly) and pass it to the GPU and through the generator
            # compute the discriminated value of the generated image, properly squeezing the output
            # get G_train_loss by using BCE_loss and the proper y_tensor
            # you are trying to make the generator generate real images
            # compute the gradients
            # step the optimizer
            #####

            z = torch.randn((mini_batch, 100)).view(-1, 100, 1, 1)
            z = Variable(z.cuda())
            G_result = G(z)

            D_result = D(G_result).squeeze()

            G_train_loss = BCE_loss(D_result, y_real_)

            G_train_loss.backward()
            G_optimizer.step()

            G_losses.append(G_train_loss.item())

            num_iter += 1

            # pdb.set_trace()

        # generate a fixed_z_ image and save
        x_gen = G(fixed_z_)
        collect_x_gen.append(x_gen.detach().clone())
        epoch_end_time = time.time()
        per_epoch_ptime = epoch_end_time - epoch_start_time

        # print out statistics
        print('[%d/%d] - ptime: %.2f, loss_d: %.3f, loss_g: %.3f' % ((epoch + 1), train_epoch, per_epoch_ptime, torch.mean(torch.FloatTensor(D_losses)),
                                                                  torch.mean(torch.FloatTensor(G_losses))))
        show_imgs(G_result[:4])

# %%
train(celeba_train_loader)
# Out:
#   0%|          | 0/1583 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 1583/1583 [52:22<00:00,  1.99s/it]
# [1/3] - ptime: 3142.50, loss_d: 0.919, loss_g: 3.551
# 100%|██████████| 1583/1583 [52:16<00:00,  1.98s/it]
# [2/3] - ptime: 3136.87, loss_d: 0.663, loss_g: 3.616
# 100%|██████████| 1583/1583 [52:18<00:00,  1.98s/it]
# [3/3] - ptime: 3138.90, loss_d: 0.508, loss_g: 4.079

# %%
for x_gen in collect_x_gen:
    show_imgs(x_gen)

# %% [markdown]
# Now generate something with your own dataset! (Fashion, Mnist, Coco, Bedrooms, Pokemon)

# %%
# Create a Dataloader for your own dataset
your_train_loader = None

# %%
G = Generator(128)
D = Discriminator(128)
G.weight_init(mean=0.0, std=0.02)
D.weight_init(mean=0.0, std=0.02)
G = G.cuda()
D = D.cuda()

# Binary Cross Entropy loss
BCE_loss = nn.BCELoss()

# Adam optimizer
G_optimizer = optim.Adam(G.parameters(), lr=lr, betas=(0.5, 0.999))
D_optimizer = optim.Adam(D.parameters(), lr=lr, betas=(0.5, 0.999))
# Train GAN
collect_x_gen = []
train(your_train_loader)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-0b8187e625e8> in <module>()
#       1 G = Generator(128)
#       2 D = Discriminator(128)
# ----> 3 G.weight_init(mean=0.0, std=0.02)
#       4 D.weight_init(mean=0.0, std=0.02)
#       5 G = G.cuda()
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1176                 return modules[name]
#    1177         raise AttributeError("'{}' object has no attribute '{}'".format(
# -> 1178             type(self).__name__, name))
#    1179
#    1180     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# AttributeError: 'Generator' object has no attribute 'weight_init'

# %%
for x_gen in collect_x_gen:
    show_imgs(x_gen)

# %% [markdown]
# # A demo of a state of the art GAN and "painting" with them in your browser:
#
# https://gandissect.csail.mit.edu
#
# By our colleagues at the MIT-IBM Watson AI Lab.

# %% [markdown]
# # Where to go from here
# * Use a more exciting datasets - check out [the pytorch torchvision.datasets](https://pytorch.org/docs/stable/torchvision/datasets.html) to get started quickly.
# * The [original GAN paper](https://papers.nips.cc/paper/5423-generative-adversarial-nets)
# * The [DCGAN paper](https://arxiv.org/abs/1511.06434) which made it all work much better for images. Start from: pytorch DCGAN [example](https://github.com/pytorch/examples/blob/master/dcgan/main.py) and [tutorial](https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html)
# * Newer generations of loss functions measure different distances between distributions $p_{data}$ and $p_G$. For example [WGAN](https://github.com/martinarjovsky/WassersteinGAN), [WGAN-GP](https://arxiv.org/abs/1704.00028), [Fisher GAN](https://arxiv.org/abs/1705.09675), [Sobolev GAN](https://arxiv.org/abs/1711.04894), many more. They often have better stability properties wrt the original GAN loss.
#
# # References for this tutorial
# * pytorch DCGAN [example](https://github.com/pytorch/examples/blob/master/dcgan/main.py) and [tutorial](https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html) by Nathan Inkawhich
# * [Medium blog post](https://medium.com/ai-society/gans-from-scratch-1-a-deep-introduction-with-code-in-pytorch-and-tensorflow-cb03cdcdba0f) by Diego Gomez Mosquera
# * [Material made for ITDS course at CUNY](https://github.com/grantmlong/itds2019/blob/master/lecture-6/DL_lab_solutions.ipynb) by Tom Sercu (that's me!)
# * [Blog post](https://towardsdatascience.com/graduating-in-gans-going-from-understanding-generative-adversarial-networks-to-running-your-own-39804c283399) by Cecelia Shao
# * [GAN overview image](https://www.slideshare.net/xavigiro/deep-learning-for-computer-vision-generative-models-and-adversarial-training-upc-2016) from Xavier Giro
